# %% [markdown]
# # Long-term Cognitive Networks for pattern classification

# %% [markdown]
# Long-term Cognitive Networks are trained with an inverse learning rule. In this model, the weights connecting the input neurons are coefficients of multiple regressions models while the weights connecting the temporal states with and outputs are computed using a learning method (the Moore–Penrose inverse method when no regularization is needed or the Ridge regression method when the model might overfit the data).

# %% [markdown]
# The syntax for the use of the LTCN classifier is compatible with scikit-learn library.

# %%
# !pip install ltcn

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import re
import numpy as np
import random
import os

from ltcn.LTCN import LTCN

from fitter import Fitter, get_common_distributions, get_distributions
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.datasets import make_friedman3, make_s_curve
from sklearn.linear_model import BayesianRidge, ElasticNet
from sklearn.model_selection import KFold, train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.neural_network import MLPClassifier

# !pip install imbalanced-learn
# !pip install lightgbm
# !pip install wittgenstein --user
# !pip install explainerdashboard --user

from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer

# for Box-Cox Transformation
from scipy import stats

# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import plotly.express as px

from tqdm import tqdm
import math

from sklearn.datasets import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

#Multilabel Stratified K Fold Creation
# !pip install iterative-stratification
import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# Out:
# Requirement already satisfied: ltcn in c:\users\mario\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\lib\site-packages (from ltcn) (1.20.3)
# Requirement already satisfied: pandas in c:\users\mario\appdata\roaming\python\python39\site-packages (from ltcn) (1.3.3)
# Requirement already satisfied: scikit-learn in c:\users\mario\anaconda3\lib\site-packages (from ltcn) (1.1.3)
# Requirement already satisfied: scipy in c:\users\mario\anaconda3\lib\site-packages (from ltcn) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas->ltcn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas->ltcn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\mario\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->ltcn) (1.16.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn->ltcn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn->ltcn) (2.2.0)
# Requirement already satisfied: imbalanced-learn in c:\users\mario\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\mario\anaconda3\lib\site-packages (from imbalanced-learn) (1.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mario\anaconda3\lib\site-packages (from imbalanced-learn) (1.20.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mario\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mario\anaconda3\lib\site-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: lightgbm in c:\users\mario\anaconda3\lib\site-packages (3.3.3)
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\lib\site-packages (from lightgbm) (1.20.3)
# Requirement already satisfied: wheel in c:\users\mario\anaconda3\lib\site-packages (from lightgbm) (0.37.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\mario\anaconda3\lib\site-packages (from lightgbm) (1.1.3)
# Requirement already satisfied: scipy in c:\users\mario\anaconda3\lib\site-packages (from lightgbm) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: wittgenstein in c:\users\mario\appdata\roaming\python\python39\site-packages (0.3.2)
# Requirement already satisfied: pandas in c:\users\mario\appdata\roaming\python\python39\site-packages (from wittgenstein) (1.3.3)
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\lib\site-packages (from wittgenstein) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas->wittgenstein) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas->wittgenstein) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mario\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->wittgenstein) (1.16.0)
# Requirement already satisfied: explainerdashboard in c:\users\mario\appdata\roaming\python\python39\site-packages (0.4.0)
# Requirement already satisfied: flask-simplelogin in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (0.1.1)
# Requirement already satisfied: dash-auth in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.4.1)
# Requirement already satisfied: joblib in c:\users\mario\anaconda3\lib\site-packages (from explainerdashboard) (1.1.0)
# Requirement already satisfied: jupyter-dash in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (0.4.2)
# Requirement already satisfied: pandas>=1.1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.3.3)
# Requirement already satisfied: click in c:\users\mario\anaconda3\lib\site-packages (from explainerdashboard) (8.0.3)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\mario\anaconda3\lib\site-packages (from explainerdashboard) (1.1.3)
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\lib\site-packages (from explainerdashboard) (1.20.3)
# Requirement already satisfied: graphviz>=0.18.2 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (0.20.1)
# Requirement already satisfied: oyaml in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.0)
# Requirement already satisfied: dash>=2.3.1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (2.7.0)
# Requirement already satisfied: dtreeviz>=1.3 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.4.1)
# Requirement already satisfied: shap>=0.37 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (0.41.0)
# Requirement already satisfied: waitress in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (2.1.2)
# Requirement already satisfied: dash-bootstrap-components>=1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from explainerdashboard) (1.2.1)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash>=2.3.1->explainerdashboard) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\mario\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (1.1.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash>=2.3.1->explainerdashboard) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mario\anaconda3\lib\site-packages (from dash>=2.3.1->explainerdashboard) (5.5.0)
# Requirement already satisfied: colour in c:\users\mario\appdata\roaming\python\python39\site-packages (from dtreeviz>=1.3->explainerdashboard) (0.1.5)
# Requirement already satisfied: matplotlib in c:\users\mario\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (3.4.3)
# Requirement already satisfied: pytest in c:\users\mario\anaconda3\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (6.2.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\mario\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\mario\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\mario\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (2.11.3)
# Requirement already satisfied: colorama in c:\users\mario\anaconda3\lib\site-packages (from click->explainerdashboard) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mario\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=2.3.1->explainerdashboard) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mario\anaconda3\lib\site-packages (from pandas>=1.1->explainerdashboard) (2.8.2)
# Requirement already satisfied: six in c:\users\mario\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.3.1->explainerdashboard) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mario\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.3.1->explainerdashboard) (8.0.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn>=1.1->explainerdashboard) (2.2.0)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\mario\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (4.62.3)
# Requirement already satisfied: packaging>20.9 in c:\users\mario\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (21.0)
# Requirement already satisfied: numba in c:\users\mario\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (0.54.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\mario\appdata\roaming\python\python39\site-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: cloudpickle in c:\users\mario\anaconda3\lib\site-packages (from shap>=0.37->explainerdashboard) (2.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mario\anaconda3\lib\site-packages (from packaging>20.9->shap>=0.37->explainerdashboard) (3.0.4)
# Requirement already satisfied: requests in c:\users\mario\anaconda3\lib\site-packages (from dash-auth->explainerdashboard) (2.26.0)
# Requirement already satisfied: flask-compress in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash-auth->explainerdashboard) (1.13)
# Requirement already satisfied: ua-parser in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash-auth->explainerdashboard) (0.16.1)
# Requirement already satisfied: chart-studio>=1.0.0 in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash-auth->explainerdashboard) (1.1.0)
# Requirement already satisfied: flask-seasurf in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash-auth->explainerdashboard) (1.1.1)
# Requirement already satisfied: retrying in c:\users\mario\appdata\roaming\python\python39\site-packages (from dash-auth->explainerdashboard) (1.3.4)
# Requirement already satisfied: brotli in c:\users\mario\appdata\roaming\python\python39\site-packages (from flask-compress->dash-auth->explainerdashboard) (1.0.9)
# Requirement already satisfied: WTForms>=2.1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from flask-simplelogin->explainerdashboard) (3.0.1)
# Requirement already satisfied: Flask-WTF<0.16.0,>=0.15.1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from flask-simplelogin->explainerdashboard) (0.15.1)
# Requirement already satisfied: ipykernel in c:\users\mario\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (6.4.1)
# Requirement already satisfied: ipython in c:\users\mario\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (7.29.0)
# Requirement already satisfied: ansi2html in c:\users\mario\appdata\roaming\python\python39\site-packages (from jupyter-dash->explainerdashboard) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\mario\anaconda3\lib\site-packages (from jupyter-dash->explainerdashboard) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1.12)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (5.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.1.2)
# Requirement already satisfied: ipython-genutils in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mario\anaconda3\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1)
# Requirement already satisfied: backcall in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (3.0.20)
# Requirement already satisfied: pygments in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (2.10.0)
# Requirement already satisfied: decorator in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\mario\anaconda3\lib\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mario\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash->explainerdashboard) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mario\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\mario\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mario\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash->explainerdashboard) (228)
# Requirement already satisfied: wcwidth in c:\users\mario\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->explainerdashboard) (0.2.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mario\anaconda3\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mario\appdata\roaming\python\python39\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mario\appdata\roaming\python\python39\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (1.3.2)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\mario\anaconda3\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.37.0)
# Requirement already satisfied: pyyaml in c:\users\mario\anaconda3\lib\site-packages (from oyaml->explainerdashboard) (6.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (21.2.0)
# Requirement already satisfied: iniconfig in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.1.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.10.0)
# Requirement already satisfied: toml in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\mario\anaconda3\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mario\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mario\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mario\anaconda3\lib\site-packages (from requests->dash-auth->explainerdashboard) (1.26.7)
# Requirement already satisfied: iterative-stratification in c:\users\mario\anaconda3\lib\site-packages (0.1.7)
# Requirement already satisfied: scipy in c:\users\mario\anaconda3\lib\site-packages (from iterative-stratification) (1.7.1)
# Requirement already satisfied: numpy in c:\users\mario\anaconda3\lib\site-packages (from iterative-stratification) (1.20.3)
# Requirement already satisfied: scikit-learn in c:\users\mario\anaconda3\lib\site-packages (from iterative-stratification) (1.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn->iterative-stratification) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mario\anaconda3\lib\site-packages (from scikit-learn->iterative-stratification) (1.1.0)

# %%
#Collect data from sensors (i.e., time-series data) installed in the manufacturing system 
ai4i2020_encoded_balanced=pd.read_csv(r'G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\raw_data\\ai4i2020_encoded_balanced.csv')
ai4i2020_encoded_balanced.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     1                298.1                    308.6                    1551
# 1     0                298.2                    308.7                    1408
# 2     0                298.1                    308.5                    1498
# 3     0                298.2                    308.6                    1433
# 4     0                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Machine failure  TWF  HDF  PWF  OSF  RNF
# 0         42.8                0                0    0    0    0    0    0
# 1         46.3                3                0    0    0    0    0    0
# 2         49.4                5                0    0    0    0    0    0
# 3         39.5                7                0    0    0    0    0    0
# 4         40.0                9                0    0    0    0    0    0

# %%
# Run in local
# Fold index
fold = 1

original_X_train = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Training Dataset" + "\\X_train_iter_" + str(fold) + ".csv")
original_X_test = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Test Dataset" + "\\X_test_iter_" + str(fold) + ".csv")

X_train = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Training Dataset" + "\\Scaled_X_train_iter_" + str(fold) + ".csv", names=['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]'])
y_train = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Training Dataset" + "\\y_train_iter_" + str(fold) + ".csv")
X_test = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Test Dataset" + "\\Scaled_X_test_iter_" + str(fold) + ".csv", names=['Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]'])
y_test = pd.read_csv('G:\\.shortcut-targets-by-id\\1-wapAl6N5YrCs68c4NiFKyvybXTXmdgZ\\Ph_D_Tyrovolas\\Our Papers\\3rd_Paper-Proposal\\Testbed Codes\\AI4I_Case_Study\\k-fold cross validation datasets\\' + str(fold) + "\\Test Dataset" + "\\y_test_iter_" + str(fold) + ".csv")

# %%
ai4i2020_encoded_balanced = ai4i2020_encoded_balanced.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
original_X_train = original_X_train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
original_X_test = original_X_test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
X_train = X_train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
X_test = X_test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
y_train = y_train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
y_test = y_test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
acc_list = []
auc_list = []
kappa_list = []

# %%
def reset_random_seeds():
    os.environ['PYTHONHASHSEED']=str(42)
    np.random.seed(42)
    random.seed(42)

def kappa_scorer(Y_pred, y_test_numpy):
    return cohen_kappa_score(y_test_numpy,Y_pred.round())

# %%
labels = y_train # here we have the classes
n_features = len(X_train.columns)+len(y_train.columns) #number of features
n_classes = len(np.unique(y_train)) #number of unique classes

# %%
from sklearn.model_selection import ParameterGrid
from tqdm.notebook import trange, tqdm

X_train_numpy = X_train.to_numpy()
y_train_numpy = y_train.to_numpy()
X_test_numpy = X_test.to_numpy()
y_test_numpy = y_test.to_numpy()


acc_list = []
auc_list = []
kappa_list = []
twf_list = []
hdf_list = []
pwf_list = []
osf_list = []
av_succ = []
comb_list = []

# hyper-parameter tuning using grid search happens here!!
param_grid = {'function': ['sigmoid', 'tanh'], 'phi': np.arange(0.5, 1.0, 0.1), 'T': [5, 10, 15], 'alpha': [0, 1.0E-2, 1.0E+2]}

grid = ParameterGrid(param_grid)

for comb in tqdm(range(0,len(grid)), desc='Combinations'):
    
    #Build the LTCN Classifier
    model = LTCN(method='inverse')
    #display("Combination " + str(comb))
    model.__init__(**grid[comb])
    model.fit(X_train_numpy,y_train_numpy)
    
    #Predictions for the test set
    y_test_pred_ltcn = model.predict(X_test_numpy)
    y_test_pred_ltcn_final = y_test_pred_ltcn.round()
    
    #Evaluation metrics for the test dataset
    accuracy_ltcn = accuracy_score(y_test_numpy, y_test_pred_ltcn.round())
    cohen_score_ltcn = cohen_kappa_score(y_test_numpy, y_test_pred_ltcn.round())
    auc_ltcn = roc_auc_score(y_test_numpy, y_test_pred_ltcn.round())

    #Append in lists
    acc_list.append(accuracy_ltcn)
    kappa_list.append(cohen_score_ltcn)
    auc_list.append(auc_ltcn)
    
    #LTCN reasoning process
    # Z : Matrix with the neurons' last activation values.
    A = X_test_numpy
    A0 = A
    Z = A0

    for t in range(model.T):
        A = model.phi * model.transform(np.matmul(A, model.W1)) + (1 - model.phi) * A0
        Z = np.concatenate((Z, A), axis=1)
    local_feature_importance_ltcn = pd.DataFrame(A, columns=['Type', 'AirtemperatureK', 'ProcesstemperatureK', 'Rotationalspeedrpm', 'TorqueNm', 'Toolwearmin'])
    
    #Find the observations' indexes that the model correctly predicted as faulty
    true_positive_indexes = []
    i=1;

    #According to the chosen model
    #For example, y_test_pred_lgbmc for LGBM Classifier
    for k in range(0,len(y_test)):
        if (y_test.loc[k,'Machinefailure']==int(y_test_pred_ltcn_final[k])) and (y_test.loc[k,'Machinefailure']==1):
            true_positive_indexes.append(k)
            i=i+1;

    #Find the observations that the selected model correctly predicted as faulty based on the previous indexes
    true_positive_observations = pd.DataFrame()
    for k in range(0,len(true_positive_indexes)):
        new_row = pd.concat([original_X_test.loc[true_positive_indexes[k],:],y_test.loc[true_positive_indexes[k],:]], axis=0)
        true_positive_observations = true_positive_observations.append(new_row, ignore_index=True)
    
    if not true_positive_observations.empty:
        
    
        true_positive_observations_with_failure_modes = pd.DataFrame()
        true_positive_observations_with_failure_modes = ai4i2020_encoded_balanced.join(true_positive_observations.set_index(['Type', 'AirtemperatureK', 'ProcesstemperatureK', 'Rotationalspeedrpm', 'TorqueNm', 'Toolwearmin', 'Machinefailure']), ['Type', 'AirtemperatureK', 'ProcesstemperatureK', 'Rotationalspeedrpm', 'TorqueNm', 'Toolwearmin', 'Machinefailure'], how='right')       
        final_true_positive_observations_with_failure_modes = true_positive_observations_with_failure_modes.reset_index(drop=True)

    
        #display("Number of true positive predictions: " + str(len(final_true_positive_observations_with_failure_modes)))

        number_of_TWF_failures_in_true_positive_predictions = 0
        number_of_HDF_failures_in_true_positive_predictions = 0
        number_of_PWF_failures_in_true_positive_predictions = 0
        number_of_OSF_failures_in_true_positive_predictions = 0
        number_of_random_failures_in_true_positive_predictions=0

        for k in range(0,len(final_true_positive_observations_with_failure_modes)):
            if final_true_positive_observations_with_failure_modes.loc[k,"TWF"]==1: #if the failure mode is TWF
                number_of_TWF_failures_in_true_positive_predictions = number_of_TWF_failures_in_true_positive_predictions + 1;
            if final_true_positive_observations_with_failure_modes.loc[k,"HDF"]==1: #if the failure mode is HDF
                number_of_HDF_failures_in_true_positive_predictions = number_of_HDF_failures_in_true_positive_predictions + 1;
            if final_true_positive_observations_with_failure_modes.loc[k,"PWF"]==1: #if the failure mode is PWF
                number_of_PWF_failures_in_true_positive_predictions = number_of_PWF_failures_in_true_positive_predictions + 1;
            if final_true_positive_observations_with_failure_modes.loc[k,"OSF"]==1: #if the failure mode is OSF
                number_of_OSF_failures_in_true_positive_predictions = number_of_OSF_failures_in_true_positive_predictions + 1;
            if (final_true_positive_observations_with_failure_modes.loc[k,"Machinefailure"]==1) and (final_true_positive_observations_with_failure_modes.loc[k,"TWF"]==0) and (final_true_positive_observations_with_failure_modes.loc[k,"HDF"]==0) and (final_true_positive_observations_with_failure_modes.loc[k,"PWF"]==0) and (final_true_positive_observations_with_failure_modes.loc[k,"OSF"]==0) and (final_true_positive_observations_with_failure_modes.loc[k,"RNF"]==0):
                number_of_random_failures_in_true_positive_predictions = number_of_random_failures_in_true_positive_predictions+1;
    
        #Calculate the correct explanations
        correct_explanations = 0
        correct_explanations_TWF = 0
        correct_explanations_HDF = 0
        correct_explanations_PWF = 0
        correct_explanations_OSF = 0

        for k in range(0,len(true_positive_observations)):
            #if the failure mode is TWF
            if final_true_positive_observations_with_failure_modes.loc[k,"TWF"]==1:
                #if tool wear is the most important feature
                if local_feature_importance_ltcn.loc[true_positive_indexes[k],"Toolwearmin"] == max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:]):
                    correct_explanations = correct_explanations+1;
                    correct_explanations_TWF = correct_explanations_TWF + 1;
                
            #if the failure mode is HDF
            if final_true_positive_observations_with_failure_modes.loc[k,"HDF"]==1: 
                maximum1 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:]) 
                maximum2 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:], key = lambda x: min(local_feature_importance_ltcn.loc[true_positive_indexes[k],:])-1 if (x == maximum1) else x)
                if (local_feature_importance_ltcn.loc[true_positive_indexes[k],"AirtemperatureK"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"AirtemperatureK"] == maximum2) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"ProcesstemperatureK"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"ProcesstemperatureK"] == maximum2):
                    correct_explanations = correct_explanations+1;
                    correct_explanations_HDF = correct_explanations_HDF + 1;
            
            
            #if the failure mode is PWF
            if final_true_positive_observations_with_failure_modes.loc[k,"PWF"]==1: 
                maximum1 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:]) 
                maximum2 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:], key = lambda x: min(local_feature_importance_ltcn.loc[true_positive_indexes[k],:])-1 if (x == maximum1) else x)
                if (local_feature_importance_ltcn.loc[true_positive_indexes[k],"Rotationalspeedrpm"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"Rotationalspeedrpm"] == maximum2) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"TorqueNm"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"TorqueNm"] == maximum2):
                    correct_explanations = correct_explanations+1;
                    correct_explanations_PWF = correct_explanations_PWF + 1;
            
            #if the failure mode is OSF        
            if final_true_positive_observations_with_failure_modes.loc[k,"OSF"]==1:
                maximum1 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:]) 
                maximum2 = max(local_feature_importance_ltcn.loc[true_positive_indexes[k],:], key = lambda x: min(local_feature_importance_ltcn.loc[true_positive_indexes[k],:])-1 if (x == maximum1) else x)
                if (local_feature_importance_ltcn.loc[true_positive_indexes[k],"Toolwearmin"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"Toolwearmin"] == maximum2) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"TorqueNm"] == maximum1) or (local_feature_importance_ltcn.loc[true_positive_indexes[k],"TorqueNm"] == maximum2):
                    correct_explanations = correct_explanations+1;
                    correct_explanations_OSF = correct_explanations_OSF + 1;
        
        denominator = 0
        
        if number_of_TWF_failures_in_true_positive_predictions != 0:
            twf_list.append(correct_explanations_TWF/number_of_TWF_failures_in_true_positive_predictions)
            twf_success = correct_explanations_TWF/number_of_TWF_failures_in_true_positive_predictions
            denominator = denominator + 1
        else:
            twf_list.append(correct_explanations_TWF)
            twf_success = 0
        if number_of_HDF_failures_in_true_positive_predictions != 0:
            hdf_list.append(correct_explanations_HDF/number_of_HDF_failures_in_true_positive_predictions)
            hdf_success = correct_explanations_HDF/number_of_HDF_failures_in_true_positive_predictions
            denominator = denominator + 1
        else:
            hdf_list.append(correct_explanations_HDF)
            hdf_success = 0
        if number_of_PWF_failures_in_true_positive_predictions != 0:
            pwf_list.append(correct_explanations_PWF/number_of_PWF_failures_in_true_positive_predictions)
            pwf_success = correct_explanations_PWF/number_of_PWF_failures_in_true_positive_predictions
            denominator = denominator + 1
        else:
            pwf_list.append(correct_explanations_PWF)
            pwf_success = 0
        if number_of_OSF_failures_in_true_positive_predictions != 0:
            osf_list.append(correct_explanations_OSF/number_of_OSF_failures_in_true_positive_predictions)
            osf_success = correct_explanations_OSF/number_of_OSF_failures_in_true_positive_predictions
            denominator = denominator + 1
        else:
            osf_list.append(correct_explanations_OSF)
            osf_success = 0
    
        average_success = (twf_success+hdf_success+pwf_success+osf_success)/denominator
        av_succ.append(average_success)
        comb_list.append(comb)
        
    
result_df = pd.DataFrame({'Accuracy': acc_list, 'AUC': auc_list, 'Kappa':kappa_list, 'TWF':twf_list, 'HDF':hdf_list, 'PWF':pwf_list, 'OSF':osf_list, 'Average Success':av_succ, 'Combinations':comb_list})
final_df = result_df.sort_values(by=['AUC'], ascending=False)
final_df = final_df.reset_index(drop=True)
best_estimator_params = grid[final_df.loc[0,"Combinations"]]
display(best_estimator_params)
# Out:
# Combinations:   0%|          | 0/90 [00:00<?, ?it/s]
# C:\Users\mario\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=2.58106e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\mario\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=6.61475e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\mario\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.81694e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\mario\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=3.14954e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\mario\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=1.41345e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
final_df
